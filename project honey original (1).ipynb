# %% [markdown]
# <font size=3 color=green>**1. Import required libraries and read the dataset.**

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\honeyproduction.csv")
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# <font size=3 color=green>**2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.**

# %%
df.head(4)
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998

# %%
df.tail(4)
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
df.shape
# Out:
# (626, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()
# Out:
# state          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# state           44
# numcol         148
# yieldpercol     95
# totalprod      517
# stocks         500
# priceperlb     210
# prodvalue      589
# year            15
# dtype: int64

# %% [markdown]
# * **The data contain 626 rows and 8 columns.**
# * **There is no null values.**
# * **There are columns of datatype int,float and object.**
# * **There is no duplicted values**

# %% [markdown]
# <font size=3 color=green>**3. Display the percentage distribution of the data in each year using the pie chart.**

# %%
df['year'].unique()
# Out:
# array([1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012], dtype=int64)

# %%
exp=(0.07,0.07, 0.07, 0.06, 0.06,0.06,0.06,0.06,0.06,0.06,0.06,0.06,0.06,0.06,0.06) 
plt.pie(x=df.year.value_counts(),explode=exp, labels=[1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
       2009, 2010, 2011, 2012],autopct='%1.2f%%',shadow=1);

# %% [markdown]
# <font color=green size=3>**4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.**

# %%
sns.displot(x=df['priceperlb'],data=df);

# %% [markdown]
# * **Most of them have priceperlb of value 1.5.**
# * **It is positively skewed.**

# %% [markdown]
# <font size=3  color=green>**5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.**

# %%
sns.scatterplot(x=df['numcol'],y=df['prodvalue']);

# %% [markdown]
# * **There is a positive correlation between Number of honey producing colonies and value of production**

# %% [markdown]
# <font size=3 color=green>**6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.**

# %%
plt.figure(figsize=(15,13))
sns.boxplot(x=df['year'],y=df['prodvalue'])
# Out:
# <Axes: xlabel='year', ylabel='prodvalue'>

# %% [markdown]
# * **Most production values are very low, it seems the productin value for all the years fall under similar range. And there are somany outliers.**

# %% [markdown]
# <font size=3 color=green>**7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')**

# %%
sns.pairplot(df, hue='year', vars=['numcol','yieldpercol','totalprod','prodvalue'],corner=1)
plt.show()

# %% [markdown]
# * **There is a positive correlation between total production and Number of honey producing colonies.**
# * **There is a positive correlation between value of production and total production.**
# * **There are no correlation between other variables.**

# %% [markdown]
# <font color=green size=3>**8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue').**

# %%
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
a=df.iloc[:,:6]
a.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70

# %%
a.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16936\2489384948.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()
#                numcol  yieldpercol  totalprod    stocks  priceperlb
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000

# %%
sns.heatmap(a.corr(),annot=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16936\3595583958.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(a.corr(),annot=True)
# <Axes: >

# %% [markdown]
# * **There is a large positive correlation (0.95) between Number of honey producing colonies and total production.**
# * **The correlation between total production and stocks held by producers is 0.88. Which means if total production increases stocks also increases.**
# * **The correlation between Number of honey producing colonies and stocks is 0.83. Which means if numcol increses stocks also increses.**
# * **Other variables have comparitively less correlation value.**
